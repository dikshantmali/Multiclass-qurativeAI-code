# %%
import pandas as pd
FILE_PATH = "../Data_Entry_2017.csv"
IMAGES_PATH = "../images_003/images"

df  = pd.read_csv(FILE_PATH)
df.shape


TARGET_DIR1 = "../My data/Atelectasis"
TARGET_DIR2 = "../My data/Consolidation"
TARGET_DIR3 = "../My data/Infiltration"
TARGET_DIR4 = "../My data/Pneumothorax"
TARGET_DIR5 = "../My data/Edema"
TARGET_DIR6 = "../My data/Emphysema"
TARGET_DIR7 = "../My data/Fibrosis"
TARGET_DIR8 = "../My data/Effusion"
TARGET_DIR9 = "../My data/Pneumonia"
TARGET_DIR10 = "../My data/Pleural_thickening"
TARGET_DIR11 = "../My data/Cardiomegaly"
TARGET_DIR12 = "../My data/Nodule"
TARGET_DIR13 = "../My data/Hernia"
TARGET_DIR14 = "../My data/No Finding"
TARGET_DIR15 = "../My data/Mass"

import os,shutil


if not os.path.exists(TARGET_DIR1):
    os.mkdir(TARGET_DIR1)
if not os.path.exists(TARGET_DIR2):
    os.mkdir(TARGET_DIR2)
if not os.path.exists(TARGET_DIR3):
    os.mkdir(TARGET_DIR3)
if not os.path.exists(TARGET_DIR4):
    os.mkdir(TARGET_DIR4)
if not os.path.exists(TARGET_DIR5):
    os.mkdir(TARGET_DIR5)
if not os.path.exists(TARGET_DIR6):
    os.mkdir(TARGET_DIR6)
if not os.path.exists(TARGET_DIR7):
    os.mkdir(TARGET_DIR7)
if not os.path.exists(TARGET_DIR8):
    os.mkdir(TARGET_DIR8)
if not os.path.exists(TARGET_DIR9):
    os.mkdir(TARGET_DIR9)
if not os.path.exists(TARGET_DIR10):
    os.mkdir(TARGET_DIR10)
if not os.path.exists(TARGET_DIR11):
    os.mkdir(TARGET_DIR11)
if not os.path.exists(TARGET_DIR12):
    os.mkdir(TARGET_DIR12)
if not os.path.exists(TARGET_DIR13):
    os.mkdir(TARGET_DIR13)
if not os.path.exists(TARGET_DIR14):
    os.mkdir(TARGET_DIR14)
if not os.path.exists(TARGET_DIR15):
    os.mkdir(TARGET_DIR15)


#1
cnt_Atelectasis = 0
for (i,row) in df.iterrows():
    if ("Atelectasis" in row["Finding Labels"]) and (row["View Position"] == "PA"):
        filename = row["Image Index"]
        image_path = os.path.join(IMAGES_PATH,filename)
        if os.path.exists(image_path):
            image_copy_path = os.path.join(TARGET_DIR1,filename)
            shutil.copy2(image_path,image_copy_path)
            cnt_Atelectasis += 1
print("Atelectasis = ",cnt_Atelectasis)





#2
cnt_Consolidation = 0
for (i,row) in df.iterrows():
    if ("Consolidation" in row["Finding Labels"]) and (row["View Position"] == "PA"):
        filename = row["Image Index"]
        image_path = os.path.join(IMAGES_PATH,filename)
        if os.path.exists(image_path):
            image_copy_path = os.path.join(TARGET_DIR2,filename)
            shutil.copy2(image_path,image_copy_path)
            cnt_Consolidation += 1
print("consolidation = ",cnt_Consolidation)





#3
cnt_Infiltration = 0
for (i,row) in df.iterrows():
    if ("Infiltration" in row["Finding Labels"]) and (row["View Position"] == "PA"):
        filename = row["Image Index"]
        image_path = os.path.join(IMAGES_PATH,filename)
        if os.path.exists(image_path):
            image_copy_path = os.path.join(TARGET_DIR3,filename)
            shutil.copy2(image_path,image_copy_path)
            cnt_Infiltration += 1
print("Infiltration = ",cnt_Infiltration)






#4
cnt_Pneumothorax = 0
for (i,row) in df.iterrows():
    if ("Pneumothorax" in row["Finding Labels"]) and (row["View Position"] == "PA"):
        filename = row["Image Index"]
        image_path = os.path.join(IMAGES_PATH,filename)
        if os.path.exists(image_path):
            image_copy_path = os.path.join(TARGET_DIR4,filename)
            shutil.copy2(image_path,image_copy_path)
            cnt_Pneumothorax += 1
print("Pneumothorax = ",cnt_Pneumothorax)





#5
cnt_Edema = 0
for (i,row) in df.iterrows():
    if ("Edema" in row["Finding Labels"]) and (row["View Position"] == "PA"):
        filename = row["Image Index"]
        image_path = os.path.join(IMAGES_PATH,filename)
        if os.path.exists(image_path):
            image_copy_path = os.path.join(TARGET_DIR5,filename)
            shutil.copy2(image_path,image_copy_path)
            cnt_Edema += 1
print("Edema = ",cnt_Edema)



#6
cnt_Emphysema = 0
for (i,row) in df.iterrows():
    if ("Emphysema" in row["Finding Labels"]) and (row["View Position"] == "PA"):
        filename = row["Image Index"]
        image_path = os.path.join(IMAGES_PATH,filename)
        if os.path.exists(image_path):
            image_copy_path = os.path.join(TARGET_DIR6,filename)
            shutil.copy2(image_path,image_copy_path)
            cnt_Emphysema += 1
print("Emphysema = ",cnt_Emphysema)




#7
cnt_Fibrosis = 0
for (i,row) in df.iterrows():
    if ("Fibrosis" in row["Finding Labels"]) and (row["View Position"] == "PA"):
        filename = row["Image Index"]
        image_path = os.path.join(IMAGES_PATH,filename)
        if os.path.exists(image_path):
            image_copy_path = os.path.join(TARGET_DIR7,filename)
            shutil.copy2(image_path,image_copy_path)
            cnt_Fibrosis += 1
print("Fibrosis = ",cnt_Fibrosis)






#8
cnt_Effusion = 0
for (i,row) in df.iterrows():
    if ("Effusion" in row["Finding Labels"]) and (row["View Position"] == "PA"):
        filename = row["Image Index"]
        image_path = os.path.join(IMAGES_PATH,filename)
        if os.path.exists(image_path):
            image_copy_path = os.path.join(TARGET_DIR8,filename)
            shutil.copy2(image_path,image_copy_path)
            cnt_Effusion += 1
print("Effusion = ",cnt_Effusion)






#9
cnt_Pneumonia = 0
for (i,row) in df.iterrows():
    if ("Pneumonia" in row["Finding Labels"]) and (row["View Position"] == "PA"):
        filename = row["Image Index"]
        image_path = os.path.join(IMAGES_PATH,filename)
        if os.path.exists(image_path):
            image_copy_path = os.path.join(TARGET_DIR9,filename)
            shutil.copy2(image_path,image_copy_path)
            cnt_Pneumonia += 1
print("Pneumonia = ",cnt_Pneumonia)





#10
cnt_Pleural_thickening = 0
for (i,row) in df.iterrows():
    if ("Pleural_Thickening" in row["Finding Labels"]) and (row["View Position"] == "PA"):
        filename = row["Image Index"]
        image_path = os.path.join(IMAGES_PATH,filename)
        if os.path.exists(image_path):
            image_copy_path = os.path.join(TARGET_DIR10,filename)
            shutil.copy2(image_path,image_copy_path)
            cnt_Pleural_thickening += 1
print("Pleural_thickening = ",cnt_Pleural_thickening)




#11
cnt_Cardiomegaly = 0
for (i,row) in df.iterrows():
    if ("Cardiomegaly" in row["Finding Labels"]) and (row["View Position"] == "PA"):
        filename = row["Image Index"]
        image_path = os.path.join(IMAGES_PATH,filename)
        if os.path.exists(image_path):
            image_copy_path = os.path.join(TARGET_DIR11,filename)
            shutil.copy2(image_path,image_copy_path)
            cnt_Cardiomegaly += 1
print("Cardiomegaly = ",cnt_Cardiomegaly)





#12
cnt_Nodule = 0
for (i,row) in df.iterrows():
    if ("Nodule" in row["Finding Labels"]) and (row["View Position"] == "PA"):
        filename = row["Image Index"]
        image_path = os.path.join(IMAGES_PATH,filename)
        if os.path.exists(image_path):
            image_copy_path = os.path.join(TARGET_DIR12,filename)
            shutil.copy2(image_path,image_copy_path)
            cnt_Nodule += 1
print("Nodule = ",cnt_Nodule)








#13
cnt_Hernia = 0
for (i,row) in df.iterrows():
    if ("Hernia" in row["Finding Labels"]) and (row["View Position"] == "PA"):
        filename = row["Image Index"]
        image_path = os.path.join(IMAGES_PATH,filename)
        if os.path.exists(image_path):
            image_copy_path = os.path.join(TARGET_DIR13,filename)
            shutil.copy2(image_path,image_copy_path)
            cnt_Hernia += 1
print("Hernia = ",cnt_Hernia)





#14
cnt_No_Finding = 0
for (i,row) in df.iterrows():
    if ("No Finding" in row["Finding Labels"]) and (row["View Position"] == "PA"):
        filename = row["Image Index"]
        image_path = os.path.join(IMAGES_PATH,filename)
        if os.path.exists(image_path):
            image_copy_path = os.path.join(TARGET_DIR14,filename)
            shutil.copy2(image_path,image_copy_path)
            cnt_No_Finding += 1
print("No Finding = ",cnt_No_Finding)




#15
cnt_Mass = 0
for (i,row) in df.iterrows():
    if ("Mass" in row["Finding Labels"]) and (row["View Position"] == "PA"):
        filename = row["Image Index"]
        image_path = os.path.join(IMAGES_PATH,filename)
        if os.path.exists(image_path):
            image_copy_path = os.path.join(TARGET_DIR15,filename)
            shutil.copy2(image_path,image_copy_path)
            cnt_Mass += 1
print("Mass = ",cnt_Mass)
# Out:
# Atelectasis =  425
# consolidation =  113
# Infiltration =  594
# Pneumothorax =  162
# Edema =  22
# Emphysema =  84
# Fibrosis =  149
# Effusion =  480
# Pneumonia =  53
# Pleural_thickening =  204
# Cardiomegaly =  244
# Nodule =  335
# Hernia =  12
# No Finding =  3560
# Mass =  231
